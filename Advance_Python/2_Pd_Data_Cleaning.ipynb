# %%
# loc and iloc for accesing cols and rows

import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.loc[:,'salary_year_avg':'salary_hour_avg']
# Out:
#         salary_year_avg  salary_hour_avg
# 0                   NaN              NaN
# 1                   NaN              NaN
# 2                   NaN              NaN
# 3                   NaN              NaN
# 4                   NaN              NaN
# ...                 ...              ...
# 785736              NaN              NaN
# 785737              NaN              NaN
# 785738              NaN              NaN
# 785739              NaN              NaN
# 785740              NaN              NaN
#
# [785741 rows x 2 columns]

# %%
median_year_salary = df['salary_year_avg'].median()
median_year_salary
# Out:
# 115000.0

# %%
median_hour_salary = df['salary_hour_avg'].median()
median_hour_salary
# Out:
# 45.97999954223633

# %%
df_filled = df
df_filled['salary_year_avg'] = df_filled['salary_year_avg'].fillna(median_year_salary )
df_filled['salary_hour_avg'] = df_filled['salary_hour_avg'].fillna(median_hour_salary)

# %%
df_unique = df_filled
df_unique = df_unique.drop_duplicates()
len(df_filled)-len(df_unique)
# Out:
# 101

# %%
df_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785640 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785640 non-null  object
#  1   job_title              785639 non-null  object
#  2   job_location           784595 non-null  object
#  3   job_via                785632 non-null  object
#  4   job_schedule_type      772975 non-null  object
#  5   job_work_from_home     785640 non-null  bool
#  6   search_location        785640 non-null  object
#  7   job_posted_date        785640 non-null  datetime64[ns]
#  8   job_no_degree_mention  785640 non-null  bool
#  9   job_health_insurance   785640 non-null  bool
#  10  job_country            785591 non-null  object
#  11  salary_rate            33066 non-null   object
#  12  salary_year_avg        785640 non-null  float64
#  13  salary_hour_avg        785640 non-null  float64
# ...

# %%
df_unique = df_unique.drop_duplicates(subset=['company_name','job_title'])
#df_unique.groupby('company_name')['job_title'].count() every compnay have 1 posted job to respective title which mearn jobs by each compnay all duplicates have been removed
df[['company_name', 'job_title']].sort_values(by=['company_name', 'job_title']).head(40 ) #how can i print table which clearly show that same company have posted job title more then one so that i can clearly see the duplication one after the another
# Out:
#                                        company_name  \
# 227539                                      "Dbank"
# 463222                             "Hamkorbank" АТБ
# 254871                                     "KELKOO"
# 522030                          "PASHA Holding" LLC
# 478518  "TECHNICUS LTD" sp. z o.o. ODDZIAŁ W POLSCE
# 153879                          "Синерик Эй Ай" ООО
# 280746                          "Синерик Эй Ай" ООО
# 519597                                  #EqualsTrue
# 682193                                  #EqualsTrue
# 377558                                  #EqualsTrue
# 707054                                  #EqualsTrue
# 713704                                  #EqualsTrue
# 441713                                  #EqualsTrue
# 634216                                  #EqualsTrue
# 697322                                  #EqualsTrue
# 238149                                  #EqualsTrue
# 58853                                   #EqualsTrue
# ...

# %%
df_1 = df_filled
df_2 = df_filled
masked_duplicate = df_1.duplicated(subset=['company_name', 'job_title'], keep='last')
dropped_rows = df_2[masked_duplicate]
print(len(dropped_rows))
dropped_rows[['company_name','job_title']].value_counts(subset=['company_name', 'job_title'])
dropped_rows.groupby('company_name')['job_title'].count()
dropped_rows.groupby('company_name')['job_title'].count().sort_values(ascending=False)
dropped_rows[['company_name', 'job_title']].sort_values(by=['company_name', 'job_title']).head(40 ) # how can i print table which clearly show that same company have posted job title more then one so that i can clearly see the duplication one after the another
# Out:
# 277699
#                                              company_name  \
# 153879                                "Синерик Эй Ай" ООО
# 519597                                        #EqualsTrue
# 377558                                        #EqualsTrue
# 441713                                        #EqualsTrue
# 58853                                         #EqualsTrue
# 301419                                      #TeamGoHealth
# 304394                                      #TeamGoHealth
# 416835                                      #TeamGoHealth
# 483866                                      #TeamGoHealth
# 754                                         #TeamGoHealth
# 120778                                      #TeamGoHealth
# 282119                                      #TeamGoHealth
# 214262                            #twiceasnice Recruiting
# 184899                            #twiceasnice Recruiting
# 67808                                       &More Interim
# ...
